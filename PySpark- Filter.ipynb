# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohit8022/PySpark/blob/main/PySpark-%20Filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Pyspark Dataframes
# - Filter Operation
# - &,|,==
# - ~

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('prectice').getOrCreate()

# %%
df_spark=spark.read.csv('test1.csv',header=True,inferSchema=True)
df_spark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
# for one filter
df_spark.filter(df_spark['salary']==18000).show()
# Out:
# +-------+---+----------+------+
# |   Name|age|Experience|Salary|
# +-------+---+----------+------+
# |Shubham| 23|         2| 18000|
# +-------+---+----------+------+
